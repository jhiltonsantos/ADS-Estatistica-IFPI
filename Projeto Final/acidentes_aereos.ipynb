# %% [markdown]
# # **Análise de dados de Acidentes Aereos (Período 2008-2018)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Objetivos
#   Identificar, através dos anos, quais os principais tipos de acidentes em cada região do país,e observar as rotas com maiores números de ocorrências.Para isso iremos levantar:<br>
#   •Apontar qual a relação entre a quantidade de acidentes e as rotas<br>  <br>•Identificar quais os principais tipo de acidentes em cada região do país;<br>
#   <br>•Observar características das aeronaves, como: ano de fabricação, modelo, tipo de motor,quantidade assentos, fabricante. E sua relação com o tipo de acidente.<br>

# %% [markdown]
# ### Links para Ajuda

# %%
# http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot
# https://towardsdatascience.com/a-guide-to-pandas-and-matplotlib-for-data-exploration-56fad95f951c

# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
from itertools import product

# %% [markdown]
# ### Funções

# %%
def tem_numero(string): # Retornar se string possue numero
  return any(char.isdigit() for char in string)

def remove_repetidos(array): # Remover Elementos Repetidos do Array
    l = []
    for i in array:
        if i not in l:
            l.append(i)
    l.sort()
    return l

# %% [markdown]
# ## Importar Dados

# %%
dados = pd.read_csv('drive/My Drive/Colab Notebooks/accidents.csv')

tabela_completa = pd.DataFrame(dados)
tabela_completa
# Out:
#       codigo_ocorrencia ocorrencia_classificacao  ... fator_87 dia_extracao
# 0       201305055424986                 ACIDENTE  ...      NÃO   2018-05-06
# 1       201805021421302                INCIDENTE  ...      NÃO   2018-05-06
# 2       201311259977425          INCIDENTE GRAVE  ...      NÃO   2018-05-06
# 3       201605160250139          INCIDENTE GRAVE  ...      NÃO   2018-05-06
# 4       201103187273112                INCIDENTE  ...      NÃO   2018-05-06
# ...                 ...                      ...  ...      ...          ...
# 5111    200811264169752                INCIDENTE  ...      NÃO   2018-05-06
# 5112    200811224318981                INCIDENTE  ...      NÃO   2018-05-06
# 5113    200810318709738                INCIDENTE  ...      NÃO   2018-05-06
# 5114    201309012098180                 ACIDENTE  ...      NÃO   2018-05-06
# 5115    200803063018556                INCIDENTE  ...      NÃO   2018-05-06
#
# [5116 rows x 116 columns]

# %%
tabela_completa.columns
# Out:
# Index(['codigo_ocorrencia', 'ocorrencia_classificacao', 'ocorrencia_tipo',
#        'ocorrencia_dia', 'ocorrencia_horario', 'ocorrencia_cidade',
#        'ocorrencia_uf', 'ocorrencia_pais', 'ocorrencia_aerodromo',
#        'aeronave_matricula',
#        ...
#        'fator_79', 'fator_80', 'fator_81', 'fator_82', 'fator_83', 'fator_84',
#        'fator_85', 'fator_86', 'fator_87', 'dia_extracao'],
#       dtype='object', length=116)

# %% [markdown]
# ### Remover Dados Que Não Serão Manipulados (Fator_*)

# %%
remover_fator = []
for i in range(1, len(dados.columns)):
  if tem_numero(dados.columns[i]) == True:
    remover_fator.append(dados.columns[i])

dados.drop(columns=remover_fator, inplace=True)

print("Quantidade de colunas: ", len(dados.columns))
dados.columns
# Out:
# Quantidade de colunas:  29
# Index(['codigo_ocorrencia', 'ocorrencia_classificacao', 'ocorrencia_tipo',
#        'ocorrencia_dia', 'ocorrencia_horario', 'ocorrencia_cidade',
#        'ocorrencia_uf', 'ocorrencia_pais', 'ocorrencia_aerodromo',
#        'aeronave_matricula', 'aeronave_equipamento', 'aeronave_fabricante',
#        'aeronave_modelo', 'aeronave_tipo_motor', 'aeronave_quantidade_motores',
#        'aeronave_peso_maximo_decolagem', 'aeronave_quantidade_assentos',
#        'aeronave_ano_fabricacao', 'aeronave_pais_registro',
#        'aeronave_categoria_registro', 'aeronave_segmento_aviacao',
#        'aeronave_origem_voo', 'aeronave_destino_voo', 'aeronave_fase_voo',
#        'aeronave_tipo_operacao', 'aeronave_nivel_dano',
#        'quantidade_fatalidades', 'quantidade_fatores_contribuintes',
#        'dia_extracao'],
#       dtype='object')

# %% [markdown]
# ### Quantidade de Dados Distintos

# %%
dados_distintos = pd.DataFrame(dados.nunique())
dados_distintos
# Out:
#                                      0
# codigo_ocorrencia                 5063
# ocorrencia_classificacao             3
# ocorrencia_tipo                     60
# ocorrencia_dia                    2680
# ocorrencia_horario                 915
# ocorrencia_cidade                  994
# ocorrencia_uf                       28
# ocorrencia_pais                      1
# ocorrencia_aerodromo               461
# aeronave_matricula                3770
# aeronave_equipamento                10
# aeronave_fabricante                205
# aeronave_modelo                    766
# aeronave_tipo_motor                  6
# aeronave_quantidade_motores          5
# aeronave_peso_maximo_decolagem     481
# aeronave_quantidade_assentos        96
# aeronave_ano_fabricacao             77
# aeronave_pais_registro               1
# aeronave_categoria_registro         33
# aeronave_segmento_aviacao           13
# aeronave_origem_voo                565
# aeronave_destino_voo               567
# aeronave_fase_voo                   30
# aeronave_tipo_operacao              10
# aeronave_nivel_dano                  5
# quantidade_fatalidades              12
# quantidade_fatores_contribuintes    21
# dia_extracao                         1

# %% [markdown]
# ### Tipos de Ocorrências

# %%
tipo_ocorrencias = dados['ocorrencia_tipo'].unique()
print("TIPOS DE OCORRENCIAS: \n", pd.DataFrame(tipo_ocorrencias))
# Out:
# TIPOS DE OCORRENCIAS:
#                                                      0
# 0                               FALHA DO MOTOR EM VOO
# 1                                           AERÓDROMO
# 2                                      POUSO SEM TREM
# 3   COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 4                                              OUTROS
# 5                           PERDA DE CONTROLE NO SOLO
# 6                                       TRÁFEGO AÉREO
# 7                                         POUSO LONGO
# 8                            PERDA DE CONTROLE EM VOO
# 9                                       INDETERMINADO
# 10                                  COM TREM DE POUSO
# 11                                    ESTOURO DE PNEU
# 12          CAUSADO POR FENÔMENO METEOROLÓGICO EM VOO
# 13                                  EXCURSÃO DE PISTA
# 14                                       POUSO BRUSCO
# 15                                          COM ROTOR
# 16                                  INCURSÃO EM PISTA
# 17                    VOO CONTROLADO CONTRA O TERRENO
# 18                        VAZAMENTO DE OUTROS FLUIDOS
# 19  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...
# 20                                    SOPRO DE REATOR
# 21                   COM PARA-BRISAS / JANELA / PORTA
# 22                         PERDA DE COMPONENTE EM VOO
# 23                     COLISÃO COM OBSTÁCULOS NO SOLO
# 24                                COM COMANDOS DE VOO
# 25          DESCOMPRESSÃO NÃO INTENCIONAL / EXPLOSIVA
# 26                               POUSO ANTES DA PISTA
# 27                                   FUMAÇA NA CABINE
# 28                                 COM PESSOAL EM VOO
# 29                        PERDA DE COMPONENTE NO SOLO
# 30                    COLISÃO DE VEÍCULO COM AERONAVE
# 31                                        FOGO EM VOO
# 32                            COM LANÇAMENTO DE CARGA
# 33                        COLISÃO DE AERONAVES EM VOO
# 34                             FALHA DO MOTOR NO SOLO
# 35                                       FOGO NO SOLO
# 36                                             F.O.D.
# 37                                     SOPRO DE ROTOR
# 38         CAUSADO POR FENÔMENO METEOROLÓGICO NO SOLO
# 39                                   SUPERAQUECIMENTO
# 40                                   FALHA ESTRUTURAL
# 41                             PROBLEMAS FISIOLÓGICOS
# 42                        POUSO EM LOCAL NÃO PREVISTO
# 43                             DESORIENTAÇÃO ESPACIAL
# 44                           VAZAMENTO DE COMBUSTÍVEL
# 45                                          PANE SECA
# 46                       COLISÃO COM AERONAVE NO SOLO
# 47                        CORTE INVOLUNTÁRIO DO MOTOR
# 48                          OPERAÇÃO A BAIXA ALTITUDE
# 49                                         COM HÉLICE
# 50                          COM LANÇAMENTO DE PESSOAS
# 51                 COLISÃO EM VOO COM OBJETO REBOCADO
# 52                       AERONAVE ATINGIDA POR OBJETO
# 53                     CORTANTE DE VENTO / TEMPESTADE
# 54                FALHA OU MAU FUNCIONAMENTO DO MOTOR
# 55                                  OPERAÇÕES NO SOLO
# 56                           RELACIONADO COM SECURITY
# 57                               PERDA DA CONSCIÊNCIA
# 58        ALARME FALSO DE FOGO OU DE SUPERAQUECIMENTO
# 59                       CONTATO ANORMAL COM A PISTA

# %% [markdown]
# ### Quantidade de Acidentes por Estados

# %%
plt.style.use("ggplot")
acidentes_uf = dados['ocorrencia_uf'].value_counts()
tabela_uf_acidentes = pd.DataFrame(acidentes_uf)
print(tabela_uf_acidentes)

#accidents_sp = (dados['ocorrencia_uf'] == 'SP').value_counts()
#accidents_sp
# Out:
#      ocorrencia_uf
# SP            1191
# RJ             496
# MG             458
# PR             428
# RS             344
# GO             263
# PA             244
# MT             238
# AM             216
# BA             206
# SC             160
# DF             154
# MS             129
# PE              87
# CE              71
# ES              66
# MA              59
# AC              52
# TO              51
# RR              51
# PI              38
# RO              28
# PB              20
# SE              19
# AL              16
# RN              15
# AP              13
# ***              3

# %% [markdown]
# ### Gráfico com Quantidade de Acidentes por UF

# %%
grafico_uf_acidentes = dados['ocorrencia_uf'].value_counts().plot(kind='pie', subplots=True, label="Quantidade de Ocorrencia por UF", figsize=(18, 18))

# %%
dados.groupby('ocorrencia_uf')['codigo_ocorrencia'].nunique().plot(kind='bar', figsize=(14, 14))
plt.show()

# %% [markdown]
# ### Adicionando Coluna "ano" aos Dados

# %%
data_ocorrencias = []
for i in range(len(dados)):
  data_ocorrencias.append(dados['ocorrencia_dia'][i])

anos_ocorrencias = []
ano = []
for i in range(len(data_ocorrencias)):
  ano.append(data_ocorrencias[i].split('-'))
  anos_ocorrencias.append(ano[i][0])

# Transformar anos para inteiro
anos_int = []
for i in range(len(anos_ocorrencias)):
  anos_int.append(int(anos_ocorrencias[i]))
anos_int

dados['ano'] = anos_int
dados.head(3)
